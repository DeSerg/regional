# %% [markdown]
# ## Read database

# %%
import pandas as pd

geonames = pd.read_csv('geonames/geonames_all.csv', '\t',
                       dtype={'altnames': object, 'cc2': object, 'acode1': object, 'acode2': object, 'acode3': object, 'acode4': object})
geonames_ = geonames[['geonameid', 'name', 'altnames', 'fclass', 'fcode', 'ccode', 'acode1', 'pop']]

# %% [markdown]
# ## All together:

# %%
# csv: ppl
print('csv: ppl')
CountriesSupported = ['RU', 'UA', 'BY', 'KZ']
ppls_sng = geonames_.ix[(bool(geonames_.fcode.notnull)) & (geonames_.fcode.str.startswith('PPL')) & (
geonames_['ccode'].isin(CountriesSupported))]

ppls_1000 = pd.read_csv('geonames/cities1000.txt', '\t',
                        dtype={'altnames': object, 'cc2': object, 'acode1': object, 'acode2': object, 'acode3': object, 'acode4': object})
ppls_1000_ = ppls_1000[['geonameid', 'name', 'altnames', 'fclass', 'fcode', 'ccode', 'acode1', 'pop']]

ppls = ppls_1000_
ppls_no_sng = ppls.ix[~(ppls['ccode'].isin(CountriesSupported))]

ppls_all = ppls_sng.append(ppls_no_sng)

print(ppls.shape, ppls_no_sng.shape)
print(ppls_sng.shape, ppls_all.shape)

ppls_all.to_csv('geonames/all_ppls.csv', sep='\t', index=False)

# csv: region
print('csv: region')
geonames_region = geonames_.ix[(bool(geonames_.fcode.notnull)) & (geonames_.fcode.str.startswith('ADM'))]
geonames_region.to_csv('geonames/all_regions.csv', sep='\t', index=False)

# csv: country
print('csv: country')
geonames_country = geonames_.ix[(bool(geonames_.fcode.notnull)) & (geonames_.fcode.str.startswith('PCL'))]
geonames_country.to_csv('geonames/all_countries.csv', sep='\t', index=False)
# Out:
# csv: ppl
# (142257, 8) (135646, 8)
# (270841, 8) (406487, 8)
# csv: region
# csv: country

# %% [markdown]
# ## Script for parsing user locations

# %%
geonames.to_csv('geonames/geonames_all.csv', sep = '\t', index=False)

# %%
CountriesSupported = ['RU', 'UA', 'BY', 'KZ']
ppls_sng = geonames_.ix[(bool(geonames_.fcode.notnull)) & (geonames_.fcode.str.startswith('PPL')) & (geonames_['ccode'].isin(CountriesSupported))]

#geonames_ppl.to_csv('geonames/all_ppls_.csv', sep = '\t', index=False)
print(ppls_sng.shape)
#print(geonames_ppl[:10])
# Out:
# (270841, 8)

# %%
print(geonames.columns)
# Out:
# Index(['geonameid', 'name', 'asciiname', 'altnames', 'lat', 'long', 'fclass',
#        'fcode', 'ccode', 'cc2', 'acode1', 'acode2', 'acode3', 'acode4', 'pop',
#        'elev', 'gtopo', 'tz', 'mdate'],
#       dtype='object')

# %%
ppls_1000 = pd.read_csv('geonames/cities1000.txt', '\t',
                       dtype={'altnames': object, 'cc2': object, 'acode1': object, 'acode2': object, 'acode3': object, 'acode4': object})
ppls_1000_ = ppls_1000[['geonameid', 'name', 'altnames', 'fclass', 'fcode', 'ccode', 'acode1', 'pop']]

# %%
ppls = ppls_1000_
ppls_no_sng = ppls.ix[~(ppls['ccode'].isin(CountriesSupported))]

# %%
ppls_all = ppls_sng.append(ppls_no_sng)

# %%
print(ppls.shape, ppls_no_sng.shape)
print(ppls_sng.shape, ppls_all.shape)
# Out:
# (142257, 8) (135646, 8)
# (270841, 8) (406487, 8)

# %%
ppls_all.to_csv('geonames/all_ppls.csv', sep = '\t', index=False)

# %%
ppls_all.ix[ppls_all['geonameid'] == 550280]
# Out:
#          geonameid    name                                           altnames  \
# 7643635     550280  Khimki  Chimkai,Chimki,Gorad Khimki,Himki,Jimki,Khimki...
#
#         fclass fcode ccode acode1
# 7643635      P   PPL    RU     47

# %%
df = pd.read_csv('geo/database/geonames_ru.csv', sep='\t')
df.ix[df['geonameid'] == 550280]
# Out:
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        geonameid    name asciiname  \
# 89578     550280  Khimki    Khimki
#
#                                                 altnames       lat      long  \
# 89578  Chimki,Himki,Khimki,Moskau-Chimki,himki,Ĥimki,...  55.89704  37.42969
#
#       fclass fcode ccode  cc2 acode1 acode2  acode3  acode4     pop  elev  \
# 89578      P   PPL    RU  NaN     48    NaN     NaN     NaN  142618   NaN
#
#        gtopo             tz       mdate
# 89578    185  Europe/Moscow  2012-01-17

# %% [markdown]
# ### PostgreSQL

# %%
import psycopg2
conn = psycopg2.connect("dbname=geonames user=deserg")

cursor = conn.cursor()
cursor.execute('CREATE INDEX ppl_idx ON geonames_ppl USING GIN (name gin_trgm_ops);')``
cursor.execute('CREATE INDEX region_idx ON geonames_region USING GIN (name gin_trgm_ops);')
cursor.execute('CREATE INDEX country_idx ON geonames_country USING GIN (name gin_trgm_ops);')
cursor.execute('select set_limit(0.55);')

# %%
levels = ['country', 'region', 'ppls']

def get_with_errs(level_ind, name):
    if level_ind < 0 or level_ind >= len(levels):
        return

    query = '''
        SELECT geonameid, name FROM geonames_{0} where '{1}' % name or '{1}' % ANY(string_to_array(altnames, ','));
    '''
    
    cursor.execute(query.format(levels[level_ind], name))
    list_tup = cursor.fetchmany()
    for tup in list_tup:
        print(tup)

def get_country_with_errs(name):
    get_with_errs(0, name)

        
def get_region_with_errs(name):
    get_with_errs(1, name)
    
def get_ppl_with_errs(name):
    get_with_errs(2, name)

# %%
import time

t = time.time()
get_region_with_errs('Kiev')
print('Time spent:', time.time() - t)
# Out:
# (6548066, 'Kieve')
# Time spent: 8.323333978652954

# %% [markdown]
# ### Parse geonames.csv

# %%
from pandas import read_csv
import pandas as pd
import numpy as np

CountriesSupported = ['RU', 'UA', 'BY', 'KZ']
Levels = ['city', 'region', 'country']
City, Region, Country = Levels[0], Levels[1], Levels[2]


def char_range(c1, c2):
    """Generates the characters from `c1` to `c2`, inclusive."""
    for c in range(ord(c1), ord(c2)+1):
        yield chr(c)

RussianLetters = set(list(char_range('а', 'я')) + list(char_range('А', 'Я')))


dfs = []
for country in [country.lower() for country in CountriesSupported]:
    dfs.append(read_csv('geo/database/geonames_' + country + '.csv', '\t', dtype = {'cc2': object, 'acode1': object, 'acode2': object}))
    
geonames = pd.concat(dfs)
geonames_cut = read_csv('geo/database/geonames_cut.csv', ';', dtype = {'cc2': object, 'acode1': object, 'acode2': object})

geonames['altnames'] = geonames['altnames'].astype('str')
geonames_cut['altnames'] = geonames_cut['altnames'].astype('str')

#print(geonames.ix[(geonames.fcode.str.startswith('PPL')) & (geonames.name.str.startswith('Mos'))])
#print(geonames.ix[geonames.name.str.contains('Oblast’')][['name', 'altnames']])

# %%
import pandas as pd

regions = pd.read_csv('geo/database/all_regions.csv', sep='\t')

loc_name = 'Санкт-Петербург'
regions.ix[(regions.name == loc_name) | ((regions.altnames.notnull) & (regions.altnames.str.contains(loc_name)))]
# Out:
#       geonameid             name  \
# 2822     536203  Sankt-Peterburg
#
#                                                altnames fclass fcode ccode  \
# 2822  Gorod-Geroy Leningrad,Leningrad,Léningrad,Pete...      A  ADM1    RU
#
#      acode1
# 2822     66

# %%
ppls = pd.read_csv('geo/database/all_ppls.csv', sep='\t')

loc_name = 'Санкт-Петербург'
ppls.ix[(ppls.name == loc_name) | ((ppls.altnames.notnull) & (ppls.altnames.str.contains(loc_name)))]
# Out:
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         geonameid              name  \
# 165425     498817  Saint Petersburg
#
#                                                  altnames fclass fcode ccode  \
# 165425  Agia Petroupole,Betuyrbukh,LED,Leningrad,Lenin...      P  PPLA    RU
#
#        acode1
# 165425     66

# %% [markdown]
# ### Parse toponims-utf8.txt

# %%
toponims = read_csv('geo/toponims-utf8.txt', '\t')

#print(toponims[toponims.])

# %% [markdown]
# ### Helper functions

# %%
import editdistance as ee
MaxEditDistance = 1

def get_records_for_location_strict(geonames, location):
    records = geonames.ix[(geonames.name == location) | (geonames.altnames.str.contains(location))]
    result = pd.DataFrame(columns = list(geonames))
    for record in records.iterrows():
        names = [record[1]['name']]
        names += record[1]['altnames'].split(',')
        if location in names:
            #print(names)
            result = result.append(record[1])
    #print(len(result))
    return result
            

def get_records_for_location_non_strict(geonames, location, max_edit_distance):
    result = pd.DataFrame(columns = list(geonames))
    edit_distances = []
    for record in geonames.iterrows():
        names = [record[1]['name']]
        names += record[1]['altnames'].split(',')
        #print(names)
        
        dists = [ee.eval(name, location) + 1 for name in names]
        dists[0] -= 1
        #print(dists)
        if max_edit_distance < 0:
            max_edit_distance = 0
        min_dist = min(dists)
        min_dist_index = dists.index(min_dist)
        
        if min_dist <= max_edit_distance:
            #print(names[min_dist_index], min_dist)
            result = result.append(record[1])
            edit_distances.append(dists[min_dist_index])
    #print(len(result))
    return (result, edit_distances)

def get_records_for_location(geonames, location, strict, max_edit_distance):
    if strict:
        return get_records_for_location_strict(geonames, location)
    else:
        return get_records_for_location_non_strict(geonames, location, max_edit_distance)

def get_records_for_code(geonames, location, fcode_start, strict = True, max_edit_distance = MaxEditDistance):
    records_for_fcode = geonames.ix[(bool(geonames.fcode.notnull)) & (geonames.fcode.str.startswith(fcode_start))]
    return get_records_for_location(records_for_fcode, location, strict, max_edit_distance)

def get_records_for_class(geonames, location, fclass, strict = True, max_edit_distance = MaxEditDistance):
    records_for_fclass = geonames.ix[geonames.fclass == fclass]
    return get_records_for_location(records_for_fclass, location, strict, max_edit_distance)

def get_records_for_region(region, country = 'RU'):
    return geonames.ix[(geonames.ccode == country) & (geonames.fcode.str.startswith('ADM')) & (geonames.acode1 == region)]

def str_equals_record(string, record):
    names = [record['name']]
    names += record['altnames'].split(',')
    return string in names

def loc_str_equals_str(database, location1, location2):
    records1 = get_records_for_code(database, location1, '')
    records2 = get_records_for_code(database, location2, '')
    for record in records1.iterrows():
        if str_equals_record(location2, record[1]):
            return True
    for record in records2.iterrows():
        if str_equals_record(location1, record[1]):
            return True
    return False
#get_records_for_code(geonames, 'Vologd', 'ADM1', False, 1)

# %% [markdown]
# ### Parse region codes

# %%
def get_region_by_capital(geonames, ppl, region, country):
    regions = get_records_for_code(geonames, ppl, 'ADM')# geonames.ix[(geonames['altnames'].str.contains(ppl)) & (geonames.fcode == 'ADM1')]
    if regions.empty:
        if not get_records_for_region(region, country).empty:
            return 'WRONG! - ' + ppl
        else:
            return ppl
    else:
        return regions.name.iloc[0]

regions_map = {}

def parse_region_map():
    codes = open('geo/admin1Codes.txt')
    
    for line in codes:
        code, name = line.split('\t', 1)
        country, region = code.split('.', 1)

        if country not in CountriesSupported:
            continue

        if (country not in regions_map.keys()) :
            regions_map[country] = {}

        try:
            int_reg = int(region)
        except ValueError:
            int_reg = -1    

        if int_reg > 0:
            region_name = get_region_by_capital(geonames, name.strip(), region, country)
            #print(region_name)
            regions_map[country][int_reg] = region_name
        elif int_reg == 0:
            country_name = name.split(' ')[0]
            regions_map[country][0] = country_name

parse_region_map()
#print(get_records_for_region('2', 'UA'))
#print(get_region_by_capital(geonames, "Luhans'ka", '2', 'UA'))
#get_records_for_region('26')
#rec.empty
#get_region_by_capital(geonames, 'Zabaïkalski', '14')
# Out:
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
#print(regions_map['RU'][0])
for country in CountriesSupported:
    for key, val in regions_map[country].items():
        if (val.startswith('WRONG!')):
            print(country, '.', key, ' - ', val, sep = '')

#regions_map['UA']
#get_region_by_capital(geonames, 'Kamchatskaya Oblast')


#[if (x == 'KOKOKOKOKOKO') x  for x in regions_map['RU'].values()]
#get_region_by_capital(geonames, 'Kamchatskaya Oblast')
#get_records_for_code(geonames, 'Jewish Autonomous Oblast', 'ADM1', False)

# %%
geonames.ix[(geonames.ccode == 'UA') & (geonames.fcode.str.startswith('ADM')) & (geonames.acode1 == '18')]
# Out:
#       geonameid                name           asciiname  \
# 9978     696634  Poltavs’ka Oblast’  Poltavs'ka Oblast'
#
#                                                altnames   lat  long fclass  \
# 9978  Oblast Poltava,Oblast Poltawa,Oblast de Poltav...  49.5  34.0      A
#
#      fcode ccode  cc2 acode1 acode2  acode3  acode4      pop  elev  gtopo  \
# 9978  ADM1    UA  NaN     18    NaN     NaN     NaN  1569479   NaN     78
#
#                      tz       mdate
# 9978  Europe/Zaporozhye  2012-08-19

# %%
#print(get_region_by_capital(geonames, 'Buryatiya'))
get_records_for_code(geonames, "Chernihivs'ka", 'ADM')
# Out:
# Empty DataFrame
# Columns: [geonameid, name, asciiname, altnames, lat, long, fclass, fcode, ccode, cc2, acode1, acode2, acode3, acode4, pop, elev, gtopo, tz, mdate]
# Index: []

# %%
import transliterate as tr

ru_codes = []
for region in regions_map['RU'].values():
    ru_codes.append((region, tr.translit(region, 'ru')))
    
#print(ru_codes)
tr.translit('эе', 'ru', reversed = True)
# Out:
# 'ee'

# %% [markdown]
# ### Read locations

# %%
loc_f = open('geo/user_source_locations.txt.sorted.uniq', 'r')

loc_arr = []

for line in loc_f:
    loc = line.strip().split(' ', 1)
    if (len(loc) == 1):
        continue
    loc = loc[1].split(',')
    loc = [s.strip() for s in loc]
    loc_arr.append(loc)


print(loc_arr[:20])
# Out:
# [['Russian Federation'], ['United States'], ['Москва', 'Москва', 'Russian Federation'], ['Москва', 'Russian Federation'], ['Ukraine'], ['Москва', 'Russian Federation'], ['Moscow', 'Москва', 'Russian Federation'], ['United Kingdom'], ['Canada'], ['California', 'United States'], ['Санкт-Петербург', 'Санкт-Петербург', 'Russian Federation'], ['Singapore'], ['Kiev', 'Ukraine'], ['New York', 'United States'], ['Санкт-Петербург', 'Russian Federation'], ['Belarus'], ['Australia'], ['Санкт-Петербург', 'Russian Federation'], ['Seattle', 'Washington', 'United States'], ['London', 'United Kingdom']]

# %% [markdown]
# ### Transliterate words

# %%
import transliterate as tr

print(tr.get_available_language_codes())
text_en = "Lorem ipsum dolor sit amet"
text_ru = "Привет, world!"
tr.translit(text_ru, 'ru', reversed = True)

loc_en = []

#for loc in loc_arr:
#    loc_en.append([translit(val, 'ru', reversed = True) for val in loc])

kyan = tr.translit('абвгдежзиклмнопрстуюфхцчшщ', 'ru', reversed = True)
print(kyan)
print(tr.translit(kyan, 'ru'))
# Out:
# ['bg', 'el', 'mk', 'uk', 'ru', 'hy', 'mn', 'l1', 'ka']
# abvgdezhziklmnoprstujufhtschshsch
# абвгдежзиклмнопрстуюфхцчшсч

# %% [markdown]
# ### Obtain combinations ["city": string, "region": string, "country": string]

# %% [markdown]
# #### get_regions(populated_place, database)

# %%
def get_regions(geonames, populated_place):
    places_df = geonames.ix[(geonames.fclass == 'P') &
    ((geonames.altnames.str.contains(populated_place)) |
     (geonames.name == populated_place))][['altnames', 'ccode', 'acode1']]
    regions = []
    for row in places_df.itertuples():
        altnames = row[1].split(',')
        if populated_place in altnames:
            country = row[2]
            try:
                region_num = int(row[3])
            except:
                region_num = 0
            region = regions_map[country][region_num]
            regions.append(region)
    return list(set(regions))

def get_countries(geonames, region):
    regions = get_records_for_code(geonames, region, 'ADM')
    countires = []
    for record in regions.iterrows():
        country_alias = record[1].ccode
        countires.append(regions_map[country_alias][0])
    return list(set(countires))

def get_info_for_ppl(geonames, ppl):
    regions = get_regions(geonames, ppl)
    info = []
    for region in regions:
        countries = get_countries(geonames, region)
        if countries:
            info += [[region, country] for country in countries]
        else:
            info.append(region)
    return info
# def unfiy_loc(location):
#     for word in location

#print(get_countries(geonames, 'Moscow'))
get_info_for_ppl(geonames, 'Нальчик')
#get_regions(geonames, 'Petropavlovsk-Kamchatskiy')
#print(geonames_full.ix[(geonames_full.fclass == 'A') & (geonames_full.altnames.str.contains('Moskva'))])
# Out:
# [['Kabardino-Balkarskaya Respublika', 'Russia']]

# %%
#0 - ppl, 1 - region, 2 - country

LocationCodes = ['PPL', 'ADM', 'PCL']
CityCode = LocationCodes[0]
RegionCode = LocationCodes[1]
CountryCode = LocationCodes[2]

def get_location_types(database, location):
    types = {0: False, 1: False, 2: False}
    for i in range(3):
        types[i] = not get_records_for_code(database, location, LocationCodes[i]).empty
    return types

def get_similar_locations(database, location, raw = True, max_edit_distance = MaxEditDistance):
    similar = {}
    for code in LocationCodes:
        records, edit_distances = get_records_for_code(database, location, code, False, max_edit_distance)
        records_list = []
        for record in records.iterrows():
            if (raw):
                records_list.append(record[1])
            else:
                records_list.append(record[1]['name'])
        similar[code] = [(records_list[i], location, edit_distances[i]) for i in range(len(records_list))]
    return similar


def get_full_similar(database, full_location, raw = True, max_edit_distance = MaxEditDistance):
    full_similar = []
    for location in full_location:
        similar = get_similar_locations(database, location, raw, max_edit_distance)
        if similar:
            full_similar.append(similar)
    return full_similar


def prepare_combinations_1(database, full_similar, result):
    if len(full_similar) != 1:
        return
    print('1!!')
    similar = full_similar[0]
    for code in LocationCodes:
        if similar[code]:
            result += [{code: pair} for pair in similar[code]]

def prepare_combinations_2(database, full_similar, result):
    if len(full_similar) != 2:
        return
    print('2!!')
    for code0 in LocationCodes:
        for code1 in LocationCodes:
            if (code0 != code1) and full_similar[0][code0] and full_similar[1][code1]:
                for pair0 in full_similar[0][code0]:
                    for pair1 in full_similar[1][code1]:
                        result.append({code0: pair0, code1: pair1})
    
def prepare_combinations_3_greater(database, full_similar, used, combination, result):
    if len(combination.keys()) == 3:
        result.append(combination.copy())
    else:
        for i in range(len(full_similar)):
            if not used[i]:
                used[i] = True
                code = LocationCodes[len(combination.keys())]
                record_pair = full_similar[i][code]
                if record_pair:
                    combination[code] = record_pair
                    prepare_combinations_3_greater(database, full_similar, used, combination, result)
                    del combination[code]
                used[i] = False


def prepare_level_data_list(multi_combination, level):
    level_pair = multi_combination[LocationCodes[level]]
    level_record_list = level_pair[0]
    level_edit_dist_list = level_pair[1]
    level_data_list = []
    for i in range(len(level_record_list)):
        record = level_record_list[i]
        edit_dist = level_edit_dist_list[i]
        level_data_list.append((record, edit_dist))
    return level_data_list

def get_possible_combinations(database, full_similar):
    combinations = []
    if (not full_similar) or (len(full_similar) > 3):
        return combinations
    
    if len(full_similar) == 1:
        prepare_combinations_1(database, full_similar, combinations)
    elif len(full_similar) == 2:
        prepare_combinations_2(database, full_similar, combinations)
    else:
        combinations_prep = []
        prepare_combinations_3_greater(database, full_similar, [False for i in range(len(full_similar))], {}, combinations_prep)
        for multi_combination in combinations_prep:
            for pair0 in multi_combination[LocationCodes[0]]:
                for pair1 in multi_combination[LocationCodes[1]]:
                    for pair2 in multi_combination[LocationCodes[2]]:
                       combinations.append({LocationCodes[0]: pair0, LocationCodes[1]: pair1, LocationCodes[2]: pair2})
    print(combinations)
    return combinations

# %%
full_location = ['Vologda', 'Vologda', 'Россия']
full_similar = get_full_similar(geonames, full_location)

# %%
print(full_similar)
#combinations = get_possible_combinations(geonames, full_similar)
# Out:
# [{'PCL': [], 'ADM': [(geonameid                                               472454
# name                                      Vologodskaya Oblast’
# asciiname                                 Vologodskaya Oblast'
# altnames     NULL,Vologda,Vologda Oblast,Vologodskaja oblas...
# lat                                                         60
# long                                                        42
# fclass                                                       A
# fcode                                                     ADM1
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.24504e+06
# elev                                                       NaN
# gtopo                                                      219
# tz                                               Europe/Moscow
# mdate                                               2012-01-16
# Name: 12033, dtype: object, 'Vologda', 1)], 'PPL': [(geonameid                                               472459
# name                                                   Vologda
# asciiname                                              Vologda
# altnames     Gorad Volagda,VGD,Vologda,Vologdae,Vólogda,Wol...
# lat                                                    59.2187
# long                                                   39.8886
# fclass                                                       P
# fcode                                                     PPLA
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                     294889
# elev                                                       NaN
# gtopo                                                      121
# tz                                               Europe/Moscow
# mdate                                               2012-01-17
# Name: 12038, dtype: object, 'Vologda', 0)]}, {'PCL': [], 'ADM': [(geonameid                                               472454
# name                                      Vologodskaya Oblast’
# asciiname                                 Vologodskaya Oblast'
# altnames     NULL,Vologda,Vologda Oblast,Vologodskaja oblas...
# lat                                                         60
# long                                                        42
# fclass                                                       A
# fcode                                                     ADM1
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.24504e+06
# elev                                                       NaN
# gtopo                                                      219
# tz                                               Europe/Moscow
# mdate                                               2012-01-16
# Name: 12033, dtype: object, 'Vologda', 1)], 'PPL': [(geonameid                                               472459
# name                                                   Vologda
# asciiname                                              Vologda
# altnames     Gorad Volagda,VGD,Vologda,Vologdae,Vólogda,Wol...
# lat                                                    59.2187
# long                                                   39.8886
# fclass                                                       P
# fcode                                                     PPLA
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                     294889
# elev                                                       NaN
# gtopo                                                      121
# tz                                               Europe/Moscow
# mdate                                               2012-01-17
# Name: 12038, dtype: object, 'Vologda', 0)]}, {'PCL': [(geonameid                                          2.01737e+06
# name                                        Russian Federation
# asciiname                                   Russian Federation
# altnames     Conaidhm na Ruise,Cónaidhm na Rúise,Den russis...
# lat                                                         60
# long                                                       100
# fclass                                                       A
# fcode                                                     PCLI
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      00
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.40702e+08
# elev                                                       NaN
# gtopo                                                      307
# tz                                                         NaN
# mdate                                               2012-01-17
# Name: 201457, dtype: object, 'Россия', 1)], 'ADM': [], 'PPL': [(geonameid                                               501257
# name                                                   Rossiya
# asciiname                                              Rossiya
# altnames     Imeni Molotova,Molotova Imeni Zernosovkhoz,Ros...
# lat                                                       52.4
# long                                                   54.9833
# fclass                                                       P
# fcode                                                      PPL
# ccode                                                       RU
# cc2                                                         RU
# acode1                                                      55
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                          0
# elev                                                       NaN
# gtopo                                                      245
# tz                                          Asia/Yekaterinburg
# mdate                                               2012-01-17
# Name: 40727, dtype: object, 'Россия', 1)]}]

# %% [markdown]
# ### Fine evaluating

# %%
FineValues = [10, 10, 10, 10]
FineMessages = [
    'Location region not equal to the region',
    'Location country not equal to region country',
    'Region country not equal to country',
    'Location country not equal to country'
]

def check_fine_1(location_region, region, fine, fine_message):
    if not str_equals_record(location_region, region):
        fine += FineValues[0]
        fine_message += FineMessages[0] + ' - ' + str(FineValues[0]) + '\n'
    return (fine, fine_message)

def check_fine_2(database, location_country, region_country, fine, fine_message):
    if not loc_str_equals_str(database, location_country, region_country):
        fine += FineValues[1]
        fine_message += FineMessages[1] + ' - ' + str(FineValues[1]) + '\n'
    return (fine, fine_message)

def check_fine_3(region_country, country, fine, fine_message):
    if not str_equals_record(region_country, country):
        fine += FineValues[2]
        fine_message += FineMessages[2] + str(FineValues[2]) + '\n'
    return (fine, fine_message)

def check_fine_4(location_country, country, fine, fine_message):
    if not str_equals_record(location_country, country):
        fine += FineValues[3]
        fine_message += FineMessages[3] + str(FineValues[3]) + '\n'
    return (fine, fine_message)

def eval_fine(database, combination):
    
    LocationCode = LocationCodes[0]
    RegionCode = LocationCodes[1]
    CountryCode = LocationCodes[2]
    
    location_exists = LocationCode in combination.keys()
    region_exists = RegionCode in combination.keys()
    country_exists = CountryCode in combination.keys()
    
    print(location_exists, region_exists, country_exists)
    
    if location_exists:
        location, location_origin, location_dist = combination[LocationCode]
    if region_exists:
        region, region_origin, region_dist = combination[RegionCode]
    if country_exists:
        country, country_origin, country_dist = combination[CountryCode]
    
    total_fine_val = 0
    total_fine_message = ''
    
    
    edit_distance_fine_val = 0
    edit_distance_fine_message = ''
    if location_exists and location_dist > 0:
        edit_distance_fine_val += location_dist
        edit_distance_fine_message += 'Location: ' + location['name'] + ' - ' + location_origin + ': ' + str(location_dist) + '\n'
    if region_exists and region_dist > 0:
        edit_distance_fine_val += region_dist
        edit_distance_fine_message += 'Region: ' + region['name'] + ' - ' + region_origin + ': ' + str(region_dist) + '\n'
    if country_exists and country_dist > 0:
        edit_distance_fine_val += country_dist
        edit_distance_fine_message += 'Country: ' + country['name'] + ' - ' + country_origin + ': ' + str(country_dist) + '\n'
    if edit_distance_fine_message:
        edit_distance_fine_message = 'Edit distance fine: \n' + edit_distance_fine_message
        total_fine_val += edit_distance_fine_val
        total_fine_message += edit_distance_fine_message
    
    
    if location_exists:
        location_info = get_info_for_ppl(database, location['name'])
    if region_exists:
        region_countries = get_countries(database, region['name'])
    
    discrepancy_fine_val = 1000
    discrepancy_fine_message = ''
    
    if location_exists and region_exists and country_exists:
        for info in location_info:
            for region_country in region_countries:
                fine = 0
                fine_message = ''
                fine, fine_message = check_fine_1(info[0], region, fine, fine_message)
                fine, fine_message = check_fine_2(database, info[1], region_country, fine, fine_message)
                fine, fine_message = check_fine_3(region_country, country, fine, fine_message)
                fine, fine_message = check_fine_4(info[1], country, fine, fine_message)
                if fine < discrepancy_fine_val:
                    discrepancy_fine_val = fine
                    discrepancy_fine_message = fine_message
    elif location_exists and region_exists:
        for info in location_info:
            for region_country in region_countries:
                fine = 0
                fine_message = ''
                fine, fine_message = check_fine_1(info[0], region, fine, fine_message)
                fine, fine_message = check_fine_2(database, info[1], region_country, fine, fine_message)
                if fine < discrepancy_fine_val:
                    discrepancy_fine_val = fine
                    discrepancy_fine_message = fine_message
    elif location_exists and country_exists:
        for info in location_info:
            fine = 0
            fine_message = ''
            fine, fine_message = check_fine_4(info[1], country, fine, fine_message)
            if fine < discrepancy_fine_val:
                discrepancy_fine_val = fine
                discrepancy_fine_message = fine_message
    elif region_exists and country_exists:
        for region_country in region_countries:
            fine = 0
            fine_message = ''
            fine, fine_message = check_fine_3(region_country, country, fine, fine_message)
            if fine < discrepancy_fine_val:
                discrepancy_fine_val = fine
                discrepancy_fine_message = fine_message
                
    if discrepancy_fine_message:
        discrepancy_fine_message = 'Discrepancy fine: \n' + discrepancy_fine_message
        total_fine_val += discrepancy_fine_val
        total_fine_message += discrepancy_fine_message

        
    return (total_fine_val, total_fine_message)

# %%
def obtain_location(database, full_location):
    full_similar = get_full_similar(database, full_location)
    print('FULL SIMILAR\n')
    combinations = get_possible_combinations(database, full_similar)
    print('COMBINATIONS\n')
    fined_combinations = []
    for combination in combinations:
        fine, message = eval_fine(database, combination)
        fined_combinations.append((combination, fine, message))
    sorted_combinations = sorted(fined_combinations, key = lambda tup: tup[1])
    
    return sorted_combinations

# %%
def ready_combinations(sorted_combinations):
    ready_combinations = []
    commented_combinations = []
    for combination_fine in sorted_combinations:
        combination, fine, message = combination_fine
        
        ready = []
        for i in range(3):
            level = Levels[i]
            code = LocationCodes[i]
            entry = combination[code][0]['name']
            ready.append(level + ': ' + entry)
        
        result = ', '.join(ready)
        ready_combinations.append(result)
        commented_combinations.append(result + ';\n' + str(fine) + ' ' + message)
    return ready_combinations, commented_combinations

# %%
loc = obtain_location(geonames, ['Dor', 'Vologda', 'Russia'])
# Out:
# FULL SIMILAR
#  [{'PCL': [], 'ADM': [], 'PPL': [(geonameid                              475633
# name                                      Bor
# asciiname                                 Bor
# altnames     Bor,Verkhne-Bor,Verkhniy Bor,Бор
# lat                                   58.5842
# long                                  55.9138
# fclass                                      P
# fcode                                     PPL
# ccode                                      RU
# cc2                                       NaN
# acode1                                     90
# acode2                                    NaN
# acode3                                    NaN
# acode4                                    NaN
# pop                                         0
# elev                                      NaN
# gtopo                                     168
# tz                         Asia/Yekaterinburg
# mdate                              2012-04-05
# Name: 15204, dtype: object, 'Dor', 1), (geonameid                          517195
# name                                  Dor
# asciiname                             Dor
# altnames     Dor,Novyy Dor,Novyy Dvor,Дор
# lat                                60.177
# long                              47.2349
# fclass                                  P
# fcode                                PPLQ
# ccode                                  RU
# cc2                                   NaN
# acode1                                 33
# acode2                                NaN
# acode3                                NaN
# acode4                                NaN
# pop                                     0
# elev                                  NaN
# gtopo                                 168
# tz                       Europe/Volgograd
# mdate                          2012-01-17
# Name: 56609, dtype: object, 'Dor', 0), (geonameid           565112
# name                  Dory
# asciiname             Dory
# altnames         Dory,Доры
# lat                58.2259
# long               37.0173
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  193
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104339, dtype: object, 'Dor', 1), (geonameid                565137
# name                        Dor
# asciiname                   Dor
# altnames     Dor,Dorovskaya,Дор
# lat                     60.6568
# long                    41.5411
# fclass                        P
# fcode                       PPL
# ccode                        RU
# cc2                         NaN
# acode1                       85
# acode2                      NaN
# acode3                      NaN
# acode4                      NaN
# pop                           0
# elev                        NaN
# gtopo                       176
# tz                Europe/Moscow
# mdate                2012-01-17
# Name: 104364, dtype: object, 'Dor', 0), (geonameid           565240
# name                  Dora
# asciiname             Dora
# altnames         Dora,Дора
# lat                59.4166
# long                37.458
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  154
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104467, dtype: object, 'Dor', 1), (geonameid           565241
# name                  Dora
# asciiname             Dora
# altnames         Dora,Дора
# lat                58.8234
# long               32.3284
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   82
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104468, dtype: object, 'Dor', 1), (geonameid           565242
# name                  Dora
# asciiname             Dora
# altnames         Dora,Дора
# lat                  58.05
# long                  34.1
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  176
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104469, dtype: object, 'Dor', 1), (geonameid           565244
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                61.1868
# long               39.8624
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  06
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  165
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104471, dtype: object, 'Dor', 0), (geonameid           565245
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                  60.95
# long               46.0833
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  170
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104472, dtype: object, 'Dor', 0), (geonameid           565246
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                60.4971
# long               40.3477
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  177
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104473, dtype: object, 'Dor', 0), (geonameid           565247
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                60.2862
# long               39.4578
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  151
# tz           Europe/Moscow
# mdate           2012-04-05
# Name: 104474, dtype: object, 'Dor', 0), (geonameid           565248
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                60.2073
# long               44.6137
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  191
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104475, dtype: object, 'Dor', 0), (geonameid           565249
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                60.1943
# long                39.515
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  160
# tz           Europe/Moscow
# mdate           2012-04-05
# Name: 104476, dtype: object, 'Dor', 0), (geonameid           565250
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                59.9095
# long               43.5842
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  145
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104477, dtype: object, 'Dor', 0), (geonameid           565251
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                59.8822
# long               39.2226
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  125
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104478, dtype: object, 'Dor', 0), (geonameid           565252
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                 59.474
# long               45.5493
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  168
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104479, dtype: object, 'Dor', 0), (geonameid           565253
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                59.4591
# long               40.2901
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  116
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104480, dtype: object, 'Dor', 0), (geonameid           565254
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                59.4173
# long               42.7929
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  186
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104481, dtype: object, 'Dor', 0), (geonameid           565255
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                  59.16
# long               40.9765
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  176
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104482, dtype: object, 'Dor', 0), (geonameid           565256
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                59.1375
# long               39.4191
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  152
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104483, dtype: object, 'Dor', 0), (geonameid           565257
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                 58.385
# long               41.2076
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  37
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  129
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104484, dtype: object, 'Dor', 0), (geonameid           565259
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                58.1167
# long                 34.95
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  189
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104486, dtype: object, 'Dor', 0), (geonameid           565260
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                58.0647
# long               35.4631
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  161
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104487, dtype: object, 'Dor', 0), (geonameid            565261
# name                   Dor’
# asciiname              Dor'
# altnames     Dor',Dor’,Дорь
# lat                 58.0333
# long                   41.1
# fclass                    P
# fcode                   PPL
# ccode                    RU
# cc2                     NaN
# acode1                   37
# acode2                  NaN
# acode3                  NaN
# acode4                  NaN
# pop                       0
# elev                    NaN
# gtopo                   123
# tz            Europe/Moscow
# mdate            2012-01-17
# Name: 104488, dtype: object, 'Dor', 1), (geonameid           565262
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                 56.779
# long               33.1638
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  268
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104489, dtype: object, 'Dor', 0), (geonameid           565263
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                56.6519
# long               33.9254
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  231
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104490, dtype: object, 'Dor', 0), (geonameid           565264
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                55.8025
# long               35.5182
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  47
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  219
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104491, dtype: object, 'Dor', 0), (geonameid           565265
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                55.6936
# long               31.7051
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  69
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  191
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104492, dtype: object, 'Dor', 0), (geonameid           565266
# name                   Dor
# asciiname              Dor
# altnames           Dor,Дор
# lat                55.3988
# long                38.162
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  47
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  132
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104493, dtype: object, 'Dor', 0), (geonameid           565362
# name                   Don
# asciiname              Don
# altnames           Don,Дон
# lat                61.6388
# long                53.895
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  34
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  112
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104588, dtype: object, 'Dor', 1), (geonameid           565725
# name                   Dol
# asciiname              Dol
# altnames           Dol,Дол
# lat                53.9778
# long               35.6873
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  25
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  202
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 104949, dtype: object, 'Dor', 1), (geonameid                           572062
# name                                   Bor
# asciiname                              Bor
# altnames     Bor,Borovskaya,Borovskoye,Бор
# lat                                65.7067
# long                               44.3865
# fclass                                   P
# fcode                                  PPL
# ccode                                   RU
# cc2                                    NaN
# acode1                                  06
# acode2                                 NaN
# acode3                                 NaN
# acode4                                 NaN
# pop                                      0
# elev                                   NaN
# gtopo                                   34
# tz                           Europe/Moscow
# mdate                           2012-04-05
# Name: 111258, dtype: object, 'Dor', 1), (geonameid                           572066
# name                                   Bor
# asciiname                              Bor
# altnames     Bor,Borovskaya,Borovskoye,Бор
# lat                                60.7566
# long                               41.1148
# fclass                                   P
# fcode                                  PPL
# ccode                                   RU
# cc2                                    NaN
# acode1                                  06
# acode2                                 NaN
# acode3                                 NaN
# acode4                                 NaN
# pop                                      0
# elev                                   NaN
# gtopo                                  179
# tz                           Europe/Moscow
# mdate                           2012-01-17
# Name: 111262, dtype: object, 'Dor', 1), (geonameid                572067
# name                        Bor
# asciiname                   Bor
# altnames     Bor,Borovskaya,Бор
# lat                     60.5879
# long                    41.4278
# fclass                        P
# fcode                       PPL
# ccode                        RU
# cc2                         NaN
# acode1                       85
# acode2                      NaN
# acode3                      NaN
# acode4                      NaN
# pop                           0
# elev                        NaN
# gtopo                       154
# tz                Europe/Moscow
# mdate                2012-01-17
# Name: 111263, dtype: object, 'Dor', 1), (geonameid           572609
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                65.5027
# long               51.9839
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  34
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   35
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111805, dtype: object, 'Dor', 1), (geonameid           572610
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                64.2833
# long               41.6985
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  06
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   35
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111806, dtype: object, 'Dor', 1), (geonameid                     572611
# name                             Bor
# asciiname                        Bor
# altnames     Bol.Bor,Bor,Бол.Бор,Бор
# lat                          63.6125
# long                         39.1207
# fclass                             P
# fcode                            PPL
# ccode                             RU
# cc2                              NaN
# acode1                            06
# acode2                           NaN
# acode3                           NaN
# acode4                           NaN
# pop                                0
# elev                             NaN
# gtopo                             40
# tz                     Europe/Moscow
# mdate                     2012-01-17
# Name: 111807, dtype: object, 'Dor', 1), (geonameid           572612
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                62.9833
# long                 42.65
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  06
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   18
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111808, dtype: object, 'Dor', 1), (geonameid           572613
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                   62.9
# long               43.0833
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  06
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   23
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111809, dtype: object, 'Dor', 1), (geonameid           572614
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                61.8518
# long                38.862
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  06
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  127
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111810, dtype: object, 'Dor', 1), (geonameid           572615
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                  61.45
# long               39.5167
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  06
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  133
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111811, dtype: object, 'Dor', 1), (geonameid           572616
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                61.0833
# long               34.4833
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   77
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111812, dtype: object, 'Dor', 1), (geonameid           572617
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                60.4833
# long               33.5167
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   16
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111813, dtype: object, 'Dor', 1), (geonameid           572618
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                60.4833
# long               33.0833
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                    1
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111814, dtype: object, 'Dor', 1), (geonameid           572619
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                  60.35
# long               34.6667
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  201
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111815, dtype: object, 'Dor', 1), (geonameid           572620
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                60.2335
# long               33.3459
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   17
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111816, dtype: object, 'Dor', 1), (geonameid           572621
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                60.1969
# long               33.8367
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   98
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111817, dtype: object, 'Dor', 1), (geonameid           572622
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                60.0361
# long               31.6742
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   24
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111818, dtype: object, 'Dor', 1), (geonameid           572623
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.9484
# long               32.5677
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   40
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111819, dtype: object, 'Dor', 1), (geonameid           572624
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.8848
# long               32.7708
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   45
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111820, dtype: object, 'Dor', 1), (geonameid           572625
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                  59.85
# long                 32.55
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   46
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111821, dtype: object, 'Dor', 1), (geonameid           572626
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.8498
# long               32.3414
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   37
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111822, dtype: object, 'Dor', 1), (geonameid           572627
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.8167
# long               39.2813
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  118
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111823, dtype: object, 'Dor', 1), (geonameid           572628
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.7696
# long               33.4762
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   52
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111824, dtype: object, 'Dor', 1), (geonameid           572629
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.5978
# long                42.313
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  115
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111825, dtype: object, 'Dor', 1), (geonameid           572630
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.5376
# long               32.0402
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   29
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111826, dtype: object, 'Dor', 1), (geonameid           572631
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                 59.462
# long               33.8195
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   84
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111827, dtype: object, 'Dor', 1), (geonameid           572632
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.4667
# long                 33.45
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   84
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111828, dtype: object, 'Dor', 1), (geonameid           572633
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.3667
# long               32.3333
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   33
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111829, dtype: object, 'Dor', 1), (geonameid           572634
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.3046
# long               36.6931
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  118
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111830, dtype: object, 'Dor', 1), (geonameid           572635
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.2754
# long                32.956
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   70
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111831, dtype: object, 'Dor', 1), (geonameid                572636
# name                        Bor
# asciiname                   Bor
# altnames     Bor,Borovskaya,Бор
# lat                     59.1908
# long                    53.0827
# fclass                        P
# fcode                       PPL
# ccode                        RU
# cc2                         NaN
# acode1                       33
# acode2                      NaN
# acode3                      NaN
# acode4                      NaN
# pop                           0
# elev                        NaN
# gtopo                       221
# tz             Europe/Volgograd
# mdate                2012-01-17
# Name: 111832, dtype: object, 'Dor', 1), (geonameid           572637
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                59.0167
# long               32.3333
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   80
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111833, dtype: object, 'Dor', 1), (geonameid           572638
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.9667
# long               30.5667
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   42
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111834, dtype: object, 'Dor', 1), (geonameid           572639
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                 58.961
# long               28.4552
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  42
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   79
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111835, dtype: object, 'Dor', 1), (geonameid                572640
# name                        Bor
# asciiname                   Bor
# altnames     Bor,Borovskaya,Бор
# lat                     58.8738
# long                    56.4416
# fclass                        P
# fcode                      PPLQ
# ccode                        RU
# cc2                         NaN
# acode1                       90
# acode2                      NaN
# acode3                      NaN
# acode4                      NaN
# pop                           0
# elev                        NaN
# gtopo                       120
# tz           Asia/Yekaterinburg
# mdate                2012-04-05
# Name: 111836, dtype: object, 'Dor', 1), (geonameid           572641
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.8667
# long               31.6333
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   36
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111837, dtype: object, 'Dor', 1), (geonameid           572642
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.8069
# long               33.3795
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   61
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111838, dtype: object, 'Dor', 1), (geonameid           572643
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.7628
# long               37.2574
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  85
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  108
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111839, dtype: object, 'Dor', 1), (geonameid           572644
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.6833
# long               32.6167
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  103
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111840, dtype: object, 'Dor', 1), (geonameid           572645
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.6412
# long               30.7085
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   51
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111841, dtype: object, 'Dor', 1), (geonameid           572646
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.5333
# long               33.7333
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   83
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111842, dtype: object, 'Dor', 1), (geonameid           572647
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.5302
# long               30.1806
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   43
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111843, dtype: object, 'Dor', 1), (geonameid           572648
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.4767
# long               32.7971
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  133
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111844, dtype: object, 'Dor', 1), (geonameid           572649
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.3018
# long               31.6904
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   25
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111845, dtype: object, 'Dor', 1), (geonameid           572650
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.2449
# long               34.6671
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  150
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111846, dtype: object, 'Dor', 1), (geonameid           572651
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.2013
# long               30.6728
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   32
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111847, dtype: object, 'Dor', 1), (geonameid           572652
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.1572
# long               31.8522
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   51
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111848, dtype: object, 'Dor', 1), (geonameid           572653
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                58.0413
# long               34.3473
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  164
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111849, dtype: object, 'Dor', 1), (geonameid           572654
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                57.9136
# long               33.2414
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  52
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  233
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111850, dtype: object, 'Dor', 1), (geonameid                572655
# name                        Bor
# asciiname                   Bor
# altnames                Bor,Бор
# lat                     57.7617
# long                    57.3283
# fclass                        P
# fcode                       PPL
# ccode                        RU
# cc2                         NaN
# acode1                       90
# acode2                      NaN
# acode3                      NaN
# acode4                      NaN
# pop                           0
# elev                        NaN
# gtopo                       170
# tz           Asia/Yekaterinburg
# mdate                2012-01-17
# Name: 111851, dtype: object, 'Dor', 1), (geonameid           572656
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                57.7747
# long               40.4056
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  88
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                   90
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111852, dtype: object, 'Dor', 1), (geonameid           572657
# name                   Bor
# asciiname              Bor
# altnames           Bor,Бор
# lat                57.6188
# long               34.9121
# fclass                   P
# fcode                  PPL
# ccode                   RU
# cc2                    NaN
# acode1                  77
# acode2                 NaN
# acode3                 NaN
# acode4                 NaN
# pop                      0
# elev                   NaN
# gtopo                  183
# tz           Europe/Moscow
# mdate           2012-01-17
# Name: 111853, dtype: object, 'Dor', 1), (geonameid           572658
# ...
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.24504e+06
# elev                                                       NaN
# gtopo                                                      219
# tz                                               Europe/Moscow
# mdate                                               2012-01-16
# Name: 12033, dtype: object, 'Vologda', 1), 'PPL': (geonameid     8.23254e+06
# name                  Bor
# asciiname             Bor
# altnames          Bor,Бор
# lat               54.8326
# long              29.0077
# fclass                  P
# fcode                 PPL
# ccode                  BY
# cc2                   NaN
# acode1                 07
# acode2                NaN
# acode3                NaN
# acode4                NaN
# pop                     0
# elev                  NaN
# gtopo                 173
# tz           Europe/Minsk
# mdate          2012-04-06
# Name: 24515, dtype: object, 'Dor', 1)}, {'PCL': (geonameid                                          2.01737e+06
# name                                        Russian Federation
# asciiname                                   Russian Federation
# altnames     Conaidhm na Ruise,Cónaidhm na Rúise,Den russis...
# lat                                                         60
# long                                                       100
# fclass                                                       A
# fcode                                                     PCLI
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      00
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.40702e+08
# elev                                                       NaN
# gtopo                                                      307
# tz                                                         NaN
# mdate                                               2012-01-17
# Name: 201457, dtype: object, 'Russia', 1), 'ADM': (geonameid                                               472454
# name                                      Vologodskaya Oblast’
# asciiname                                 Vologodskaya Oblast'
# altnames     NULL,Vologda,Vologda Oblast,Vologodskaja oblas...
# lat                                                         60
# long                                                        42
# fclass                                                       A
# fcode                                                     ADM1
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.24504e+06
# elev                                                       NaN
# gtopo                                                      219
# tz                                               Europe/Moscow
# mdate                                               2012-01-16
# Name: 12033, dtype: object, 'Vologda', 1), 'PPL': (geonameid     8.23276e+06
# name                  Bor
# asciiname             Bor
# altnames          Bor,Бор
# lat               54.8655
# long              29.8534
# fclass                  P
# fcode                 PPL
# ccode                  BY
# cc2                   NaN
# acode1                 07
# acode2                NaN
# acode3                NaN
# acode4                NaN
# pop                     0
# elev                  NaN
# gtopo                 152
# tz           Europe/Minsk
# mdate          2012-04-06
# Name: 24741, dtype: object, 'Dor', 1)}, {'PCL': (geonameid                                          2.01737e+06
# name                                        Russian Federation
# asciiname                                   Russian Federation
# altnames     Conaidhm na Ruise,Cónaidhm na Rúise,Den russis...
# lat                                                         60
# long                                                       100
# fclass                                                       A
# fcode                                                     PCLI
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      00
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.40702e+08
# elev                                                       NaN
# gtopo                                                      307
# tz                                                         NaN
# mdate                                               2012-01-17
# Name: 201457, dtype: object, 'Russia', 1), 'ADM': (geonameid                                               472454
# name                                      Vologodskaya Oblast’
# asciiname                                 Vologodskaya Oblast'
# altnames     NULL,Vologda,Vologda Oblast,Vologodskaja oblas...
# lat                                                         60
# long                                                        42
# fclass                                                       A
# fcode                                                     ADM1
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.24504e+06
# elev                                                       NaN
# gtopo                                                      219
# tz                                               Europe/Moscow
# mdate                                               2012-01-16
# Name: 12033, dtype: object, 'Vologda', 1), 'PPL': (geonameid     8.33087e+06
# name                  Bor
# asciiname             Bor
# altnames          Bor,Бор
# lat               54.1085
# long              29.7539
# fclass                  P
# fcode                 PPL
# ccode                  BY
# cc2                   NaN
# acode1                 06
# acode2                NaN
# acode3                NaN
# acode4                NaN
# pop                     0
# elev                  NaN
# gtopo                 163
# tz           Europe/Minsk
# mdate          2012-06-07
# Name: 28823, dtype: object, 'Dor', 1)}, {'PCL': (geonameid                                          2.01737e+06
# name                                        Russian Federation
# asciiname                                   Russian Federation
# altnames     Conaidhm na Ruise,Cónaidhm na Rúise,Den russis...
# lat                                                         60
# long                                                       100
# fclass                                                       A
# fcode                                                     PCLI
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      00
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.40702e+08
# elev                                                       NaN
# gtopo                                                      307
# tz                                                         NaN
# mdate                                               2012-01-17
# Name: 201457, dtype: object, 'Russia', 1), 'ADM': (geonameid                                               472454
# name                                      Vologodskaya Oblast’
# asciiname                                 Vologodskaya Oblast'
# altnames     NULL,Vologda,Vologda Oblast,Vologodskaja oblas...
# lat                                                         60
# long                                                        42
# fclass                                                       A
# fcode                                                     ADM1
# ccode                                                       RU
# cc2                                                        NaN
# acode1                                                      85
# acode2                                                     NaN
# acode3                                                     NaN
# acode4                                                     NaN
# pop                                                1.24504e+06
# elev                                                       NaN
# gtopo                                                      219
# tz                                               Europe/Moscow
# mdate                                               2012-01-16
# Name: 12033, dtype: object, 'Vologda', 1), 'PPL': (geonameid    1.51889e+06
# name                 Sor
# asciiname            Sor
# altnames             nan
# lat              50.2709
# long             80.2198
# fclass                 P
# fcode                PPL
# ccode                 KZ
# cc2                  NaN
# acode1                00
# acode2               NaN
# acode3               NaN
# acode4               NaN
# pop                    0
# elev                 NaN
# gtopo                233
# tz           Asia/Almaty
# mdate         2012-02-28
# Name: 7879, dtype: object, 'Dor', 1)}]
# True True True
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# True True True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     876         try:
# --> 877             result = op(x, y)
#     878         except TypeError:
#
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/pandas/core/ops.py in <lambda>(x, y)
#     124                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 125                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     126                                    names('rand_'), op('&')),
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     894                         y = bool(y)
# --> 895                     result = lib.scalar_binop(x, y, op)
#     896                 except:
#
# pandas/lib.pyx in pandas.lib.scalar_binop (pandas/lib.c:16399)()
#
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/pandas/core/ops.py in <lambda>(x, y)
#     124                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 125                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     126                                    names('rand_'), op('&')),
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-674b0f1f67e3> in <module>()
# ----> 1 loc = obtain_location(geonames, ['Dor', 'Vologda', 'Russia'])
#
# <ipython-input-40-3a775a02d137> in obtain_location(database, full_location)
#       6     fined_combinations = []
#       7     for combination in combinations:
# ----> 8         fine, message = eval_fine(database, combination)
#       9         fined_combinations.append((combination, fine, message))
#      10     sorted_combinations = sorted(fined_combinations, key = lambda tup: tup[1])
#
# <ipython-input-22-bdf452602921> in eval_fine(database, combination)
#      85                 fine_message = ''
#      86                 fine, fine_message = check_fine_1(info[0], region, fine, fine_message)
# ---> 87                 fine, fine_message = check_fine_2(database, info[1], region_country, fine, fine_message)
#      88                 fine, fine_message = check_fine_3(region_country, country, fine, fine_message)
#      89                 fine, fine_message = check_fine_4(info[1], country, fine, fine_message)
#
# <ipython-input-22-bdf452602921> in check_fine_2(database, location_country, region_country, fine, fine_message)
#      14
#      15 def check_fine_2(database, location_country, region_country, fine, fine_message):
# ---> 16     if not loc_str_equals_str(database, location_country, region_country):
#      17         fine += FineValues[1]
#      18         fine_message += FineMessages[1] + ' - ' + str(FineValues[1]) + '\n'
#
# <ipython-input-4-03b36f936974> in loc_str_equals_str(database, location1, location2)
#      62 def loc_str_equals_str(database, location1, location2):
#      63     records1 = get_records_for_code(database, location1, '')
# ---> 64     records2 = get_records_for_code(database, location2, '')
#      65     for record in records1.iterrows():
#      66         if str_equals_record(location2, record[1]):
#
# <ipython-input-4-03b36f936974> in get_records_for_code(geonames, location, fcode_start, strict, max_edit_distance)
#      45
#      46 def get_records_for_code(geonames, location, fcode_start, strict = True, max_edit_distance = MaxEditDistance):
# ---> 47     records_for_fcode = geonames.ix[(bool(geonames.fcode.notnull)) & (geonames.fcode.str.startswith(fcode_start))]
#      48     return get_records_for_location(records_for_fcode, location, strict, max_edit_distance)
#      49
#
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other)
#     927                       is_integer_dtype(np.asarray(other)) else fill_bool)
#     928             return filler(self._constructor(
# --> 929                 na_op(self.values, other),
#     930                 index=self.index)).__finalize__(self)
#     931
#
# /Users/deserg/anaconda2/envs/snakes/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     897                     raise TypeError("cannot compare a dtyped [{0}] array with "
#     898                                     "a scalar of type [{1}]".format(
# --> 899                                         x.dtype, type(y).__name__))
#     900
#     901         return result
#
# TypeError: cannot compare a dtyped [object] array with a scalar of type [bool]

# %%
r, c = ready_combinations(loc)
c
# Out:
# ['city: Vologda, region: Vologodskaya Oblast’, country: Russian Federation; 2 Edit distance fine: \nRegion: Vologodskaya Oblast’ - Vologda: 1\nCountry: Russian Federation - Russia: 1\n',
#  'city: Vologda, region: Vologodskaya Oblast’, country: Russian Federation; 2 Edit distance fine: \nRegion: Vologodskaya Oblast’ - Vologda: 1\nCountry: Russian Federation - Russia: 1\n']

# %%
import re

line = 'kokok <<Location><o>a, b</o></Location>dsd<<Location><o>d, a, b</o></Location>'

p = re.compile('<<Location><o>(.*?)</o></Location>')

al = re.findall(p, line)

for s in al:
    old_loc = '<<Location><o>' + s + '</o></Location>'
    new_loc = '<<Location><o>' + 'WOW' + s + 'UU'  + '</o></Location>'
    line = line.replace(old_loc, new_loc)

print(line)
loc = p.search(line).group(1)
loc = loc.split(',')
loc = [s.strip() for s in loc]


print(','.join(['s', 'd']))
# Out:
# kokok <<Location><o>WOWa, bUU</o></Location>dsd<<Location><o>WOWd, a, bUU</o></Location>
# s,d

# %%
def get_cyrillic_name(record):
    names = [record['name']] + record['altnames'].split(',')
    max_inters = 0
    max_name = names[0]
    for name in names:
        inters = 0
        for char in name:
            if char in RussianLetters:
                inters += 1
        if inters > max_inters:
            print(inters, name)
            max_inters = inters
            max_name = name
    return max_name

#print(combinations[0])
series = combinations[0]['PCL'][0]
get_cyrillic_name(combinations[0]['PCL'][0])
# Out:
# 4 Орос
# 17 Расійская Федэрацыя
# 19 Российская Федерация
# 'Российская Федерация'
